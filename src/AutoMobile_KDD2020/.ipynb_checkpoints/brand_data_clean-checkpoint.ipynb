# %%
import pandas as pd
from urllib.parse import urlparse

# %%
df = pd.read_json("actionshoesoffical.json")

# %%
# json_files = ['hushpuppies_in.json','paragon.json','actionshoesoffical.json','inc5_official.json',
#               'redchief.json','campusshoes.json','khadimsindia.json','redtapeindia.json','catwalk_in.json',
#               'lancer.json','skechersindia.json','clarksshoes.json','leecooper.json','sparx.json',
#               'converseindia.json','metroshoesindia.json','vanhuesen.json','crocsindia.json','mochishoesin.json',
#               'filaindia.json','northstar.json']

# %%
import copy
import pandas as pd
from urllib.parse import urlparse

def create_new_instance(tagged_user_info, original_data):
    new_instance = copy.deepcopy(original_data)
    tagged_user_id = tagged_user_info['id']
    tagged_user_username = tagged_user_info['username']
    new_instance['influencerId'] = tagged_user_id
    new_instance['influencerUsername'] = tagged_user_username
    return new_instance

def extract_brand_name(instagram_url):
    parsed_url = urlparse(instagram_url)
    path_segments = parsed_url.path.strip('/').split('/')
    return path_segments[0] if path_segments else None

def process_data(input_df):
    new_instances = []

    for index, row in input_df.iterrows():
        tagged_users_info = row['taggedUsers']
        if isinstance(tagged_users_info, list):
            new_instances.extend([create_new_instance(tagged_user_info, row.to_dict()) for tagged_user_info in tagged_users_info])

    new_df = pd.DataFrame(new_instances)
    new_df['brand_name'] = new_df['inputUrl'].apply(extract_brand_name)

    columns_to_drop = ['id','type','inputUrl','shortCode','mentions','url','firstComment','latestComments',
                         'dimensionsHeight','dimensionsWidth','displayUrl','images','timestamp',
                         'childPosts','isSponsored','ownerFullName','ownerUsername','ownerId'
                         ,'videoUrl','alt','productType','isPinned','locationId','taggedUsers',
                         'locationName']
    new_df = new_df.drop(columns=columns_to_drop, axis=1)
    return new_df

json_files = ['anitadongre_apify.json', 'bibaindia_apify.json', 'leejeansindia_apify.json', 'lifestylestores_apify.json', 'shoppers_stop_apiy.json']
main_df = pd.concat([pd.read_json(f'./data/Brands/Cloth/{file}') for file in json_files], ignore_index=True)
processed_main_df = process_data(main_df)
processed_main_df = processed_main_df[processed_main_df['brand_name'] != processed_main_df['influencerUsername']]
processed_main_df.reset_index(drop=True, inplace=True)

# %%
processed_main_df
# Out:
#                                                 caption  \
# 0     “Our world is not ours alone. Humanity can onl...
# 1     “Our world is not ours alone. Humanity can onl...
# 2     “Our world is not ours alone. Humanity can onl...
# 3     @iamamyjackson in Anita Dongre.\n\nOutfit 1 - ...
# 4     @malaikaaroraofficial paired our Symphony Of T...
# ...                                                 ...
# 2924  Thinking what to gift your bestie this #Friend...
# 2925  Thinking what to gift your bestie this #Friend...
# 2926  Thinking what to gift your bestie this #Friend...
# 2927  Thinking what to gift your bestie this #Friend...
# 2928  This #FriendshipDay gift your bestie timeless ...
#
#                                                hashtags  commentsCount  \
# 0     [BeKindRewild, AnitaDongreRewild, Rewild23, an...             68
# 1     [BeKindRewild, AnitaDongreRewild, Rewild23, an...             68
# 2     [BeKindRewild, AnitaDongreRewild, Rewild23, an...             68
# 3                             [AmyJackson, AnitaDongre]              8
# 4                           [MalaikaArora, AnitaDongre]             14
# ...                                                 ...            ...
# 2924  [FriendshipDay, EndOfSeasonSale, MySaleMyWay, ...              7
# 2925  [FriendshipDay, EndOfSeasonSale, MySaleMyWay, ...              7
# 2926  [FriendshipDay, EndOfSeasonSale, MySaleMyWay, ...              7
# 2927  [FriendshipDay, EndOfSeasonSale, MySaleMyWay, ...              7
# 2928  [FriendshipDay, EndOfSeasonSale, MySaleMyWay, ...             20
#
#       likesCount  videoViewCount  videoPlayCount  videoDuration  \
# 0           3878         43114.0        177491.0         59.256
# 1           3878         43114.0        177491.0         59.256
# 2           3878         43114.0        177491.0         59.256
# 3           4772             NaN             NaN            NaN
# 4           5096             NaN             NaN            NaN
# ...          ...             ...             ...            ...
# 2924         312             NaN             NaN            NaN
# 2925         312             NaN             NaN            NaN
# 2926         312             NaN             NaN            NaN
# 2927         312             NaN             NaN            NaN
# 2928         595             NaN             NaN            NaN
#
#       paidPartnership sponsors influencerId    influencerUsername  \
# 0                 NaN      NaN    388280968        elephantfamily
# 1                 NaN      NaN   4032856966             ncf.india
# 2                 NaN      NaN  53333988160          dongreanita_
# 3                 NaN      NaN     30440277         iamamyjackson
# 4                 NaN      NaN   1277111693  malaikaaroraofficial
# ...               ...      ...          ...                   ...
# 2924              NaN      NaN  36842270787             fossil.in
# 2925              NaN      NaN    471392291         skagendenmark
# 2926              NaN      NaN    314828264       policelifestyle
# 2927              NaN      NaN   4327107918         giordanoindia
# 2928              NaN      NaN    195080159     titanwatchesindia
#
#          brand_name
# 0       anitadongre
# 1       anitadongre
# 2       anitadongre
# 3       anitadongre
# 4       anitadongre
# ...             ...
# 2924  shoppers_stop
# 2925  shoppers_stop
# 2926  shoppers_stop
# 2927  shoppers_stop
# 2928  shoppers_stop
#
# [2929 rows x 12 columns]

# %%
processed_main_df['influencerUsername'].unique().shape
# Out:
# (792,)

# %%
processed_main_df.to_json('./data/Brands/Cloth/Cloth_brands_preprocessed.json')

# %%
df = pd.read_json('./data/Brands/Cloth/anitadongre_apify.json')

# %%
df.shape
# Out:
# (1001, 32)

# %%
df2 = pd.read_json('./data/Brands/Shoes/filaindia.json')

# %%
df2.shape
# Out:
# (1845, 33)

# %%
df2.columns
# Out:
# Index(['inputUrl', 'id', 'type', 'shortCode', 'caption', 'hashtags',
#        'mentions', 'url', 'commentsCount', 'firstComment', 'latestComments',
#        'dimensionsHeight', 'dimensionsWidth', 'displayUrl', 'images',
#        'videoUrl', 'alt', 'likesCount', 'videoViewCount', 'videoPlayCount',
#        'timestamp', 'childPosts', 'ownerFullName', 'ownerUsername', 'ownerId',
#        'productType', 'videoDuration', 'isSponsored', 'isPinned',
#        'taggedUsers', 'paidPartnership', 'locationName', 'locationId'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['inputUrl', 'id', 'type', 'shortCode', 'caption', 'hashtags',
#        'mentions', 'url', 'commentsCount', 'firstComment', 'latestComments',
#        'dimensionsHeight', 'dimensionsWidth', 'displayUrl', 'images',
#        'videoUrl', 'alt', 'likesCount', 'videoViewCount', 'videoPlayCount',
#        'timestamp', 'childPosts', 'ownerFullName', 'ownerUsername', 'ownerId',
#        'productType', 'videoDuration', 'isSponsored', 'taggedUsers',
#        'isPinned', 'locationName', 'locationId'],
#       dtype='object')

# %%
df.head()
# Out:
#                                 inputUrl                   id     type  \
# 0  https://www.instagram.com/anitadongre  3228379930236442624    Video
# 1  https://www.instagram.com/anitadongre  3301818390359729664  Sidecar
# 2  https://www.instagram.com/anitadongre  3304747244421110784  Sidecar
# 3  https://www.instagram.com/anitadongre  3303928437042733056    Image
# 4  https://www.instagram.com/anitadongre  3230027037962052608    Video
#
#      shortCode                                            caption  \
# 0  CzNgnEdvlgM  “Our world is not ours alone. Humanity can onl...
# 1  C3SalUOPmVi  HAND-PAINTED WITH LOVE\n\nCrafted by master ar...
# 2  C3c0hwIK9xu  HAND-PAINTED IN JAIPUR\n\nEach piece is indivi...
# 3  C3Z6WiVPl8R  Consciously crafted Vegan Accessories that are...
# 4  CzTXHpEoqQC  A magical weekend, our fashion fundraiser show...
#
#                                             hashtags  \
# 0  [BeKindRewild, AnitaDongreRewild, Rewild23, an...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [AnitaDongreRewild, BeKindRewild, thecitypalac...
#
#                                             mentions  \
# 0       [ncf.india, elephantfamily, sreedharelephas]
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [gauravikumari, pachojaipur, theroyalfamilyofj...
#
#                                         url  commentsCount firstComment  ...  \
# 0  https://www.instagram.com/p/CzNgnEdvlgM/             68          ❤️👏  ...
# 1  https://www.instagram.com/p/C3SalUOPmVi/              4         Mast  ...
# 2  https://www.instagram.com/p/C3c0hwIK9xu/              5           Pp  ...
# 3  https://www.instagram.com/p/C3Z6WiVPl8R/              0               ...
# 4  https://www.instagram.com/p/CzTXHpEoqQC/            277  Amazing 🔥❤️  ...
#
#   ownerFullName  ownerUsername    ownerId productType videoDuration  \
# 0  Anita Dongre    anitadongre  368146821       clips        59.256
# 1  Anita Dongre    anitadongre  368146821         NaN           NaN
# 2  Anita Dongre    anitadongre  368146821         NaN           NaN
# 3  Anita Dongre    anitadongre  368146821         NaN           NaN
# 4  Anita Dongre    anitadongre  368146821       clips        56.354
#
#   isSponsored                                        taggedUsers  isPinned  \
# 0       False  [{'full_name': 'Elephant Family', 'id': '38828...       1.0
# 1       False                                                NaN       NaN
# 2       False                                                NaN       NaN
# 3       False                                                NaN       NaN
# 4       False                                                NaN       1.0
#
#                                 locationName   locationId
# 0                                        NaN          NaN
# 1                                        NaN          NaN
# 2                                        NaN          NaN
# 3                                        NaN          NaN
# 4  The City Palace, Jaipur, Rajasthan, India  426878205.0
#
# [5 rows x 32 columns]

# %%
df['ownerUsername'].unique()
# Out:
# array(['filaindia', 'shauryapratapsinha', 'ujjwaldhir', 'noughtone01',
#        'settlesubtle', 'lumsleeshdiaries', 'shreejarajgopal',
#        'cwaayalsingh', 'teajaygil', 'ayeshakanga', 'nainabee', 'zeynshaw',
#        'vardhanpuri02', 'jiggyjacob_', 'jeet_tailor', 'bhavna.kashyap_',
#        'iamnkhl', 'sagarsheldekar', 'jsfilmsindia', 'aditya_rana',
#        'zerxeswadia'], dtype=object)

# %%
df.columns
# Out:
# Index(['inputUrl', 'id', 'type', 'shortCode', 'caption', 'hashtags',
#        'mentions', 'url', 'commentsCount', 'firstComment', 'latestComments',
#        'dimensionsHeight', 'dimensionsWidth', 'displayUrl', 'images',
#        'videoUrl', 'alt', 'likesCount', 'videoViewCount', 'videoPlayCount',
#        'timestamp', 'childPosts', 'ownerFullName', 'ownerUsername', 'ownerId',
#        'productType', 'videoDuration', 'isSponsored', 'isPinned',
#        'taggedUsers', 'paidPartnership', 'locationName', 'locationId'],
#       dtype='object')

# %%
processed_main_df.columns
# Out:
# Index(['caption', 'hashtags', 'commentsCount', 'likesCount', 'videoViewCount',
#        'videoPlayCount', 'videoDuration', 'paidPartnership', 'sponsors',
#        'username', 'fullName', 'biography', 'externalUrl',
#        'externalUrlShimmed', 'followersCount', 'followsCount', 'hasChannel',
#        'highlightReelCount', 'isBusinessAccount', 'joinedRecently',
#        'businessCategoryName', 'private', 'verified', 'profilePicUrl',
#        'profilePicUrlHD', 'facebookPage', 'igtvVideoCount', 'relatedProfiles',
#        'latestIgtvVideos', 'postsCount', 'latestPosts', 'influencerId',
#        'influencerUsername', 'brand_name'],
#       dtype='object')
